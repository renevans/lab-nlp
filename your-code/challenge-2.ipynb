# %% [markdown]
# # Challenge 2: Sentiment Analysis
#
# In this challenge we will learn sentiment analysis and practice performing sentiment analysis on Twitter tweets.
#
# ## Introduction
#
# Sentiment analysis is to *systematically identify, extract, quantify, and study affective states and subjective information* based on texts ([reference](https://en.wikipedia.org/wiki/Sentiment_analysis)). In simple words, it's to understand whether a person is happy or unhappy in producing the piece of text. Why we (or rather, companies) care about sentiment in texts? It's because by understanding the sentiments in texts, we will be able to know if our customers are happy or unhappy about our products and services. If they are unhappy, the subsequent action is to figure out what have caused the unhappiness and make improvements.
#
# Basic sentiment analysis only understands the *positive* or *negative* (sometimes *neutral* too) polarities of the sentiment. More advanced sentiment analysis will also consider dimensions such as agreement, subjectivity, confidence, irony, and so on. In this challenge we will conduct the basic positive vs negative sentiment analysis based on real Twitter tweets.
#
# NLTK comes with a [sentiment analysis package](https://www.nltk.org/api/nltk.sentiment.html). This package is great for dummies to perform sentiment analysis because it requires only the textual data to make predictions. For example:
#
# ```python
# >>> from nltk.sentiment.vader import SentimentIntensityAnalyzer
# >>> txt = "Ironhack is a Global Tech School ranked num 2 worldwide. Our mission is to help people transform their careers and join a thriving community of tech professionals that love what they do."
# >>> analyzer = SentimentIntensityAnalyzer()
# >>> analyzer.polarity_scores(txt)
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.8442}
# ```
#
# In this challenge, however, you will not use NLTK's sentiment analysis package because in your Machine Learning training in the past 2 weeks you have learned how to make predictions more accurate than that. The [tweets data](https://www.kaggle.com/kazanova/sentiment140) we will be using today are already coded for the positive/negative sentiment. You will be able to use the Naïve Bayes classifier you learned in the lesson to predict the sentiment of tweets based on the labels.

# %% [markdown]
# ## Conducting Sentiment Analysis
#
# ### Loading and Exploring Data
#
# The dataset we'll be using today is located on Kaggle (https://www.kaggle.com/kazanova/sentiment140). Once you have downloaded and imported the dataset, it you will need to define the columns names: df.columns = ['target','id','date','flag','user','text']
#
# *Notes:*
#
# * The dataset is huuuuge (1.6m tweets). When you develop your data analysis codes, you can sample a subset of the data (e.g. 20k records) so that you will save a lot of time when you test your codes.

# %%
# your code here

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\renev\lab-nlp\training.1600000.processed.noemoticon.csv', header = None)

# %%
df.shape
# Out:
# (1600000, 6)

# %%
df.head()
# Out:
#    0           1                             2         3                4  \
# 0  0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY  _TheSpecialOne_
# 1  0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY    scotthamilton
# 2  0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY         mattycus
# 3  0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          ElleCTF
# 4  0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY           Karoli
#
#                                                    5
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1  is upset that he can't update his Facebook by ...
# 2  @Kenichan I dived many times for the ball. Man...
# 3    my whole body feels itchy and like its on fire
# 4  @nationwideclass no, it's not behaving at all....

# %%
df.columns = ['target','id','date','flag','user','text']

# %%
df
# Out:
#          target          id                          date      flag  \
# 0             0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1             0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2             0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3             0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4             0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1599995       4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996       4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997       4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998       4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999       4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text
# 0        _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          scotthamilton  is upset that he can't update his Facebook by ...
# 2               mattycus  @Kenichan I dived many times for the ball. Man...
# 3                ElleCTF    my whole body feels itchy and like its on fire
# 4                 Karoli  @nationwideclass no, it's not behaving at all....
# ...                  ...                                                ...
# 1599995  AmandaMarie1028  Just woke up. Having no school is the best fee...
# 1599996      TheWDBoards  TheWDB.com - Very cool to hear old Walt interv...
# 1599997           bpbabe  Are you ready for your MoJo Makeover? Ask me f...
# 1599998     tinydiamondz  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999   RyanTrevMorris  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [1600000 rows x 6 columns]

# %% [markdown]
# ### Prepare Textual Data for Sentiment Analysis
#
# Now, apply the functions you have written in Challenge 1 to your whole data set. These functions include:
#
# * `clean_up()`
#
# * `tokenize()`
#
# * `stem_and_lemmatize()`
#
# * `remove_stopwords()`
#
# Create a new column called `text_processed` in the dataframe to contain the processed data. At the end, your `text_processed` column should contain lists of word tokens that are cleaned up. Your data should look like below:
#
# ![Processed Data](data-cleaning-results.png)

# %%
# your code here

# %%
import re

# %%
def clean_up(s):
    return re.sub(r"http\S+|[^A-Za-z]", " ", s.lower())

# %%
# %%time
df['text_processed'] = df['text'].apply(clean_up)
# Out:
# Wall time: 8.29 s

# %%
df['text_processed']
# Out:
# 0           switchfoot     awww  that s a bummer   you sh...
# 1          is upset that he can t update his facebook by ...
# 2           kenichan i dived many times for the ball  man...
# 3            my whole body feels itchy and like its on fire
# 4           nationwideclass no  it s not behaving at all ...
#                                  ...
# 1599995    just woke up  having no school is the best fee...
# 1599996    thewdb com   very cool to hear old walt interv...
# 1599997    are you ready for your mojo makeover  ask me f...
# 1599998    happy   th birthday to my boo of alll time    ...
# 1599999    happy  charitytuesday  thenspcc  sparkscharity...
# Name: text_processed, Length: 1600000, dtype: object

# %%
# The remove_stopwords function took too long on the entire dataset.  So I will sample before running this function.

sample_df = df.sample(n=20000, replace=False, random_state=1)

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
def tokenize(s):
    return word_tokenize(s)

# %%
# %%time
sample_df['text_processed'] = sample_df['text_processed'].apply(tokenize)
# Out:
# Wall time: 1.63 s

# %%
from nltk.stem import WordNetLemmatizer 
from nltk.stem import PorterStemmer
from nltk.corpus import wordnet

# %%
ps = PorterStemmer()
lemmatizer = WordNetLemmatizer() 
def stem_and_lemmatize(l):

    stem_list = [ps.stem(w) for w in l]
    return (stem_list)

    lemmatized_list = [lemmatizer.lemmatize(word) for word in stem_list]
    return (lemmatized_list)

# %%
# %%time
sample_df['text_processed'] = sample_df['text_processed'].apply(stem_and_lemmatize)
# Out:
# Wall time: 3.21 s

# %%
sample_df
# Out:
#          target          id                          date      flag  \
# 514293        0  2190584004  Tue Jun 16 03:08:48 PDT 2009  NO_QUERY
# 142282        0  1881451988  Fri May 22 04:42:15 PDT 2009  NO_QUERY
# 403727        0  2058252964  Sat Jun 06 14:34:17 PDT 2009  NO_QUERY
# 649503        0  2237307600  Fri Jun 19 05:34:22 PDT 2009  NO_QUERY
# 610789        0  2224301193  Thu Jun 18 09:20:06 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1200592       4  1985525470  Sun May 31 17:16:16 PDT 2009  NO_QUERY
# 333050        0  2013234007  Tue Jun 02 22:12:13 PDT 2009  NO_QUERY
# 893698        4  1691979761  Sun May 03 19:01:16 PDT 2009  NO_QUERY
# 1145456       4  1977778758  Sat May 30 21:41:26 PDT 2009  NO_QUERY
# 837125        4  1558676973  Sun Apr 19 09:05:04 PDT 2009  NO_QUERY
#
#                 user                                               text  \
# 514293     Vicki_Gee  i miss nikki nu nu already  shes always there ...
# 142282     PatCashin  So I had a dream last night. I  remember a sig...
# 403727   deelectable  @girlyghost ohh poor sickly you   (((hugs)) ho...
# 649503   justinekepa                               it is raining again
# 610789      cmatt007          @MissKeriBaby wish I was in LA right now
# ...              ...                                                ...
# 1200592  cydconverse  I get the worst writer's cramp. These thank yo...
# 333050     k8janfaza        @ladyinreddress the sun is all gone now...
# 893698     fadyfresh  FINALLY a break till Wed, no work OR school, b...
# 1145456   xCoreBorex                            I want a Blackberry...
# 837125    Sabrinieee  in montrea doing some much needed ocean swimmi...
#
#                                             text_processed
# 514293   [i, miss, nikki, nu, nu, alreadi, she, alway, ...
# 142282   [so, i, had, a, dream, last, night, i, rememb,...
# 403727   [girlyghost, ohh, poor, sickli, you, hug, hope...
# 649503                               [it, is, rain, again]
# 610789     [misskeribabi, wish, i, wa, in, la, right, now]
# ...                                                    ...
# 1200592  [i, get, the, worst, writer, s, cramp, these, ...
# 333050      [ladyinreddress, the, sun, is, all, gone, now]
# 893698   [final, a, break, till, wed, no, work, or, sch...
# 1145456                           [i, want, a, blackberri]
# 837125   [in, montrea, do, some, much, need, ocean, swi...
#
# [20000 rows x 7 columns]

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\renev\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def remove_stopwords(l):
    word_list = []
    for word in l:
        if word not in stopwords.words():
            word_list.append(word)
    return word_list

# %%
# %%time
sample_df['text_processed'] = sample_df['text_processed'].apply(remove_stopwords)
# Out:
# Wall time: 31min 29s

# %%
# we often remove punctuation after tokenization since punctuation is unlikely to be a good predictive feature

# %%
def remove_punctuation (l):
    no_punctuation  = [word for word in l if word.isalnum()]
    return (no_punctuation )

# %%
# %%time
sample_df['text_processed'] = sample_df['text_processed'].apply(remove_punctuation)
# Out:
# Wall time: 41.7 ms

# %%
sample_df
# Out:
#          target          id                          date      flag  \
# 514293        0  2190584004  Tue Jun 16 03:08:48 PDT 2009  NO_QUERY
# 142282        0  1881451988  Fri May 22 04:42:15 PDT 2009  NO_QUERY
# 403727        0  2058252964  Sat Jun 06 14:34:17 PDT 2009  NO_QUERY
# 649503        0  2237307600  Fri Jun 19 05:34:22 PDT 2009  NO_QUERY
# 610789        0  2224301193  Thu Jun 18 09:20:06 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1200592       4  1985525470  Sun May 31 17:16:16 PDT 2009  NO_QUERY
# 333050        0  2013234007  Tue Jun 02 22:12:13 PDT 2009  NO_QUERY
# 893698        4  1691979761  Sun May 03 19:01:16 PDT 2009  NO_QUERY
# 1145456       4  1977778758  Sat May 30 21:41:26 PDT 2009  NO_QUERY
# 837125        4  1558676973  Sun Apr 19 09:05:04 PDT 2009  NO_QUERY
#
#                 user                                               text  \
# 514293     Vicki_Gee  i miss nikki nu nu already  shes always there ...
# 142282     PatCashin  So I had a dream last night. I  remember a sig...
# 403727   deelectable  @girlyghost ohh poor sickly you   (((hugs)) ho...
# 649503   justinekepa                               it is raining again
# 610789      cmatt007          @MissKeriBaby wish I was in LA right now
# ...              ...                                                ...
# 1200592  cydconverse  I get the worst writer's cramp. These thank yo...
# 333050     k8janfaza        @ladyinreddress the sun is all gone now...
# 893698     fadyfresh  FINALLY a break till Wed, no work OR school, b...
# 1145456   xCoreBorex                            I want a Blackberry...
# 837125    Sabrinieee  in montrea doing some much needed ocean swimmi...
#
#                                             text_processed
# 514293     [miss, nikki, alreadi, alway, need, thank, xxx]
# 142282   [dream, last, night, rememb, sign, clearli, to...
# 403727   [girlyghost, ohh, poor, sickli, hug, hope, fee...
# 649503                                              [rain]
# 610789                     [misskeribabi, wish, wa, right]
# ...                                                    ...
# 1200592  [get, worst, writer, cramp, thank, note, kill,...
# 333050                         [ladyinreddress, sun, gone]
# 893698   [final, break, wed, work, school, hectic, yay,...
# 1145456                                       [blackberri]
# 837125            [montrea, much, need, ocean, swim, surf]
#
# [20000 rows x 7 columns]

# %% [markdown]
# ### Creating Bag of Words
#
# The purpose of this step is to create a [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) from the processed data. The bag of words contains all the unique words in your whole text body (a.k.a. *corpus*) with the number of occurrence of each word. It will allow you to understand which words are the most important features across the whole corpus.
#
# Also, you can imagine you will have a massive set of words. The less important words (i.e. those of very low number of occurrence) do not contribute much to the sentiment. Therefore, you only need to use the most important words to build your feature set in the next step. In our case, we will use the top 5,000 words with the highest frequency to build the features.
#
# In the cell below, combine all the words in `text_processed` and calculate the frequency distribution of all words. A convenient library to calculate the term frequency distribution is NLTK's `FreqDist` class ([documentation](https://www.nltk.org/api/nltk.html#module-nltk.probability)). Then select the top 5,000 words from the frequency distribution.

# %%
# your code here

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.probability import ConditionalFreqDist
import numpy as np

# %%
# all_words = nltk.FreqDist(sample_df['clean_blob'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'clean_blob'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-223-175ac3da8395> in <module>
# ----> 1 all_words = nltk.FreqDist(sample_df['clean_blob'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'clean_blob'

# %%
all_words
# Out:
# FreqDist({'good morn': 8, 'good morn everyon': 5, 'headach': 4, 'isplay ha die sorri': 4, 'pack': 4, 'goodnight': 4, 'tummi ach': 3, 'so tire': 3, 'happi mother s day': 3, 'happi mother day': 3, ...})

# %%
all_words.most_common(5000)
# Out:
# [('good morn', 8),
#  ('good morn everyon', 5),
#  ('headach', 4),
#  ('isplay ha die sorri', 4),
#  ('pack', 4),
#  ('goodnight', 4),
#  ('tummi ach', 3),
#  ('so tire', 3),
#  ('happi mother s day', 3),
#  ('happi mother day', 3),
#  ('not feel well', 3),
#  ('get readi for work', 3),
#  ('at work', 3),
#  ('hello world', 2),
#  ('best of youtub the bird amp the bee the bird amp the bee subscirbeee amp leav a comment make a',
#   2),
#  ('just woke up', 2),
#  ('i dunno what to do', 2),
#  ('my stomach hurt', 2),
#  ('i have a headach', 2),
#  ('back to work', 2),
#  ('workformeonlin i didn t understand that tri command like buy tag or sell tag',
#   2),
#  ('lay out by the pool', 2),
#  ('my throat hurt', 2),
#  ('it s my birthday', 2),
#  ('my tummi hurt', 2),
#  ('thi one is for you free market mangoorang', 2),
#  ('thi is a statu updat to twitter from ice timestamp mon jun cest', 2),
#  ('read', 2),
#  ('work from to', 2),
#  ('i need a drink', 2),
#  ('i miss you', 2),
#  ('work on father day', 2),
#  ('jog isnt realli that cool especi if you ve got a fever', 2),
#  ('scari dream', 2),
#  ('i m so tire', 2),
#  ('couldn t sleep', 2),
#  ('gfalcon morn gi hmm do you know what breed the love presley is is it french bulldog ahh curiou he s so cute xxx',
#   2),
#  ('my teeth hurt', 2),
#  ('watch big brother', 2),
#  ('my head hurt', 2),
#  ('good day', 2),
#  ('i miss nikki nu nu alreadi she alway there when need thank u xxx', 1),
#  ('so i had a dream last night i rememb a sign which clearli told me where to get a job i can t remem what the sign said',
#   1),
#  ('girlyghost ohh poor sickli you hug hope you feel a littl better soon', 1),
#  ('it is rain again', 1),
#  ('misskeribabi wish i wa in la right now', 1),
#  ('nala olowalu still ha a full tummi from bread basket', 1),
#  ('macintom site doesn t seem to want to load up they must be get a lot of hit',
#   1),
#  ('time for some sleep hav to actual do some work tmrw', 1),
#  ('supercoolkp in oxford that month', 1),
#  ('time for a cup of tea and fruit bagel i m go to turn the day around', 1),
#  ('just finish play asshol first time nd place second time st place heh', 1),
#  ('final got me some green bad the dog kept tryna get all up in my mix i guess she want some green now i m snifflin and sneezin',
#   1),
#  ('babimattivi nhaaaiiiiiiiiiii me rendi ao twitter fim de agosto to na rea hein',
#   1),
#  ('poor kitti didn t make it last night lost more and nurs anoth tonight', 1),
#  ('mrpope ok that wa cooler than than the search engin launch', 1),
#  ('alexalltimelow so upset i couldnt go', 1),
#  ('dev and we shouldn t have constant rain', 1),
#  ('good morn folk last week of school woohoo joy joy joy down in my heart have a spectacular day love to all extra to ram',
#   1),
#  ('even on my happiest of day see other sad make me sad', 1),
#  ('i should be celebr but you re not here xhumonn sorri i asn t abl to call wa on the fon with koo t chuchu i miss you poo',
#   1),
#  ('troublepandapr i use tu have a at least time but kept get the rrod so i shift tu tha ps',
#   1),
#  ('hmmm wonder if my plan will actual happen today lay in bed', 1),
#  ('ddlovatofan oh k good luck with that lol', 1),
#  ('she shine fangirl squee', 1),
#  ('ok aoif goin mad she hate twitter she think it sad sad thing for peop s hu have no live that wors then gaa someon callin it gaaa',
#   1),
#  ('ugh feel like death warm up all of us are sick no bueno', 1),
#  ('all in for repair', 1),
#  ('cristayyy i wan na see it too i misss youuuu boooo', 1),
#  ('eat chocol bout to watch dr who again miss jacob alreadi', 1),
#  ('hey younglo i been showin u luv n nothin back from ya no show donna no luv no more young lo tv live gt',
#   1),
#  ('pushplaynick quot grandpa want an ice chest and some beef quot georg lopez rulesss',
#   1),
#  ('finish homework minut after they made the final board call sprint on to plane at last minut didn t even get to eat mcd s',
#   1),
#  ('gettin readi to cupcak ju ditch my cuzin fo him sooooo he betta make it wurth it',
#   1),
#  ('here is heaven on earth and a new one it seem', 1),
#  ('i do not now nor ever will trust the structur integr of roller coaster henc i will not ride them',
#   1),
#  ('at er with seren who ha been vomit for four day now and can t keep ani liquid down',
#   1),
#  ('phoenixritu thn u hv anoth option come yo my home', 1),
#  ('kimkardashian get readi for mtv movi award see u there', 1),
#  ('jason mccartney is an absolut legend and such a role model', 1),
#  ('feel like cr p today bark like a dog and now the hayfev is start groan', 1),
#  ('annzoo and you said i wa the weird one who couldn t read', 1),
#  ('drummrboy i can t', 1),
#  ('think someon ha shart themselv on thi train', 1),
#  ('my finger are like prune waaaaa i hate that feel when they feel powderi and weird ughh',
#   1),
#  ('movi gon na see up', 1),
#  ('i am go to fail my math a level tomorrow', 1),
#  ('nikker but i want her i need to invent a love potion dip cupid s arrow in it then shove it deep in her right buttock',
#   1),
#  ('hawleydawley so sorri', 1),
#  ('krystynzilla honestli you re amaz thank you', 1),
#  ('richardwatkinsj she just get our name mix up i just think it s normal for her well i hope',
#   1),
#  ('yeah so physio wa crap still about a month away from ani form of real physic activ couldnt even sit and straignthen my leg',
#   1),
#  ('nice sunni day today take the sun chair out of storag and gon na sit in the back garden with my stereo a good book and glass of wine',
#   1),
#  ('go to bed', 1),
#  ('sharmain awww we have same promblem my dear i hate it', 1),
#  ('sorri tweepl i m still feel pretti miser so my tweet isn t up to par', 1),
#  ('got ta go on a prescript diaper rash cream run thi afternoon poor kiddo',
#   1),
#  ('no more j amp k', 1),
#  ('done now i can relax', 1),
#  ('is ach all over', 1),
#  ('we had basebal game on sunday we lose saturday and sunday were realli sunnu',
#   1),
#  ('is not go to the gym today my shoulder hurt from get bang up at the u w hockey tournament last night need to rest it',
#   1),
#  ('karenbyrn i am watch churchonlin but i can t get the chat to work', 1),
#  ('thi girl wa about to sit next to me on the bu but we made eye contact right befor she did so she got up and move to anoth seat',
#   1),
#  ('the bu wa extrem earli today bet few peopl miss it bit not me', 1),
#  ('head to pullmonst to pack up my apart back tomorrow in time for more wakeboard',
#   1),
#  ('me and chloe are twitter bum everyon', 1),
#  ('lolyl you still have exam', 1),
#  ('badminton with jan shim and friend work out time', 1),
#  ('must fight urg to go to botcon', 1),
#  ('wait for my friend to ring i want to go to bed', 1),
#  ('maureen met the white tie affair last night woo woo like one of the best night of my life they are so talent and nice lt lt lt',
#   1),
#  ('omg i cant stop love adrian jajajajaja you re so funni i cant wait for see you the next week',
#   1),
#  ('is love xna the offici tutori howev is voic by the most boringli slow guy ever video amp all he ha done is drawn a sprite',
#   1),
#  ('wow thunder too my grandpa use to tell me the sound of thunder wa god bowl',
#   1),
#  ('amylovesoliv meleahrubino ye sound like pink eye i also had an ulcer of the eye and it did that too',
#   1),
#  ('just came home from franc le man rule', 1),
#  ('thisisryanross waitin for new patd album hope it ll come out soon', 1),
#  ('ozdj that s evil i want an a twitter bird', 1),
#  ('itsmegregori just so you know i don t like you one bit', 1),
#  ('jocal hope our wish come true someday', 1),
#  ('just got done distribut postcard for our a month websit i love my job', 1),
#  ('kateweb haha i know what a ridicuk scene love it though', 1),
#  ('just realiz that it now guy in my life from chicago who turn out not to be what i thought they were chicago prick appar',
#   1),
#  ('dudaac bom show', 1),
#  ('i know i m be aw annoy but i ain t stop andyhurleyday andyhurleyday andyhurleyday andyhurleyday lt',
#   1),
#  ('pleas rememb you need a helmet for the bike asap talk to you later ok hope your head not to bad',
#   1),
#  ('hi peep anoth sunni day in northern ireland make a bloodi chang gon na wait til it warmer ghen im gon na catch some ray',
#   1),
#  ('all my prayer goe out to rodney rodger and hi fam he wa paralyz from the neck down in a bike accid',
#   1),
#  ('track grrl it s not on my cb', 1),
#  ('rachrud helllooooooo munchkin', 1),
#  ('lemziipi and me i hope d haha yeah sorri for not be on alot tonight talk to you tomorrow though promis d night xx',
#   1),
#  ('check to see who may have saud creek wine in stock label under jame river cellar for now',
#   1),
#  ('away from my wife on our th anniversari sad', 1),
#  ('pen lvr they frown on us googl alcohol at work', 1),
#  ('serenebab well as long as it s use for good thing i guess pavlov wa alright',
#   1),
#  ('gumbo love and alirenco ha boy issu', 1),
#  ('must get into scc basketbal next term', 1),
#  ('had a great afternoon at the lake with the gommel s realli stink that i have to go to work tomorrow',
#   1),
#  ('i feel neglect sad', 1),
#  ('how can we enjoy our yr togeth mayb we will becom good fren after tat but i will tell him tomolo morn we shld both tri hard',
#   1),
#  ('off to the gym to get happi and healthi', 1),
#  ('t m realli like the cm', 1),
#  ('rajivshivan i know the answer to the last question in that link', 1),
#  ('dentaldiva thank you', 1),
#  ('tweetre es niceee', 1),
#  ('wish carriehoush didn t have to work father day', 1),
#  ('omg dannywood hi comment about hi b day amp hi mom not bake hi cake ha got me in flood i miss my daddi',
#   1),
#  ('flu ed up to the hilt s listen to ibizasonica radio no lucozad no orang juic',
#   1),
#  ('ahhh my pictur don t work', 1),
#  ('ughhhhh back to school tomorrow onli ok a lot of day until summer vacat',
#   1),
#  ('pinkwaterfairi wonder ring look super cool i love steampunk goodi', 1),
#  ('said goodby to meng mei tonight', 1),
#  ('i wa point out hubbi s gray in hi facial hair n he said it wa prematur age ualtion what a dork brook',
#   1),
#  ('on my way back from the beach', 1),
#  ('is go to walk to the librari', 1),
#  ('the blizzard reward for complet a good mi ride yesterday wa also part of ragbrai train',
#   1),
#  ('jkissnhug just mention you on twc', 1),
#  ('fossiloflif don t say that maan hasn t he won enough', 1),
#  ('mornin twitter s happi saturdayi xx', 1),
#  ('it so hot im dread have to walk around downtown in thi heat', 1),
#  ('wickedground i read a realli good one of him about back in the lotr day about him and miranda otto eowyn i can t find it',
#   1),
#  ('kate cute background my dear', 1),
#  ('blockhead eva yay i ll look so it wa never on an album', 1),
#  ('exam exam', 1),
#  ('jonasbroth jona muchbett jona blackkey amp jona turnright are my top fav love you so much can t wait till june th',
#   1),
#  ('studi again get sick of thi c mooon it s summer time', 1),
#  ('firefox is hate on my luv for songzyuuup by freez but that s probabl for the best',
#   1),
#  ('zerolab air mac pro android base', 1),
#  ('good mornin everybodi happi mother day to everi mom', 1),
#  ('iamadamfierc adammmmmm i kept come to see you tonight but you were bisi',
#   1),
#  ('stay up late tonight to talk to you again', 1),
#  ('chrisdjmoyl when are you head back up to leed', 1),
#  ('back from the stadium nant renn too bad we could not keep the', 1),
#  ('quot back into my old way my old way with you quot', 1),
#  ('hey guy i wont be on youtub alot im go to parti thi week sorri', 1),
#  ('hotword for now i am sleepi good night peopl', 1),
#  ('is go to a retir parti', 1),
#  ('ljsbabi good morn to you', 1),
#  ('time for hw', 1),
#  ('i sob sob miss the hill alreadi', 1),
#  ('my mom s so funni hear the music through her ipod', 1),
#  ('dougiemcfli dougi my dog ha hi name', 1),
#  ('peterlisney how the jigsaw experi go i hope juli get a lot of interest she the best book keeper ever',
#   1),
#  ('greatscott up is both in d and d depend on locat best to call or check websit',
#   1),
#  ('ugh i don t wan na go to driver ed', 1),
#  ('whi did kingston wind follow me home', 1),
#  ('michaelmcclari definit when are you go to come and visit us you bring silverlight info we ll get the pasti readi',
#   1),
#  ('spin kosso tell me you fiz amp eric are to thank for find the amaz beatbox video thank you directli',
#   1),
#  ('feel depress today i need cheer up', 1),
#  ('thi rain is serious depress me read the book new moon is definit not help as well',
#   1),
#  ('good news i got a bike bad news my car is die good news i have a bike now in case my car die',
#   1),
#  ('jayd nicol i hear that girl', 1),
#  ('kirstytbsmcr it wa amazinggg they play carpathia new again amp sink into me and they sound great the energi wa amaz too',
#   1),
#  ('i m miss the war', 1),
#  ('panda we re both awesom', 1),
#  ('revis time i want to go out', 1),
#  ('no iphon updat today', 1),
#  ('mvchase ha i did it again now don t touch it', 1),
#  ('breakuphelp i m glad to hear that have a heart to heart talk peac mayb thing will get better good luck and god bless',
#   1),
#  ('ouch that concert wa pain but we were the highlight and that s good for us',
#   1),
#  ('barbylon how wa montgomeri the scienc on a sphere wa broken at mcwane', 1),
#  ('jameschau mayb we did t get the inform of your come to our univers in apirl',
#   1),
#  ('dinafragola we did some star and put them on the ceil lol it look great',
#   1),
#  ('i just delet of the peopl i had on facebook talk about refresh it s like my homepag is actual stuff i want to see now',
#   1),
#  ('kurono ilov thi rain i think imma go outsid', 1),
#  ('hate whn my doc is right on drsadrieh said wk til foot norm i lafd day hvi walkng amp swollen beynd shoe cab today then',
#   1),
#  ('roseisroadkil sure i wouldn t mind it s annabelledestini hotmail com', 1),
#  ('vincefalconi ouch', 1),
#  ('decid not to go i want to see my sweeti but i can t', 1),
#  ('think to myself whi is it that when you re happi someon alway ha to bring you down',
#   1),
#  ('covergirl oh no sorri just the one i found', 1),
#  ('i miss berni mac eva shall he live through our laughter amp joy', 1),
#  ('wow i wa up in time for a macdonnald breakfast haven t had one for year nom nom still count if i ve not gone to bed right',
#   1),
#  ('mohdismail saya yg repli', 1),
#  ('littlefletch i think it would be great if you upload some pictur of your draw they are wonder xx',
#   1),
#  ('onthestereo sam whi would you ever', 1),
#  ('quit worri about my fianc he s all poorli and there s noth i can do to help',
#   1),
#  ('kyranoffici good on you', 1),
#  ('i just sound obsses ha', 1),
#  ('ele maaaan i dont wan na talk about it calc brought me down and i brought u umm some wisdom ohh the great thing i saw',
#   1),
#  ('love the new pocket god icon they get better and better with each updat',
#   1),
#  ('weizenbaum nope just tri be quot stimul quot fwiw', 1),
#  ('petshopboy how about a visit to hall the birthplac of g f handel next week it s nearbi leipzig and a veri beauti citi',
#   1),
#  ('maxwellvintag i see twitter as a social parti and the unexpect could result in veri posit direct for peopl',
#   1),
#  ('sb websit is have problem', 1),
#  ('bc ticketmast doesn t work phone line are busi amp my brother still sleep i m give up no ticket for me',
#   1),
#  ('day of sun in a row for dublin still can t get over it had to top off the car all day',
#   1),
#  ('fun day in the sun at the airport shoot the chopper dialogu scene no stunt yet',
#   1),
#  ('sakasama no chou upsid down butterfli', 1),
#  ('stay home w mom and the kid today spring break what a nice cool day for fl thi time of year for a low tonight in april',
#   1),
#  ('i just paid in tax on a textbook i am not a happi person', 1),
#  ('wow everyth is piss me off right now i feel like yell at my sheet i almost hope thi is just pm or someth',
#   1),
#  ('pandamayhem right and toilet lol she come everi other week so i can just do a quick onc over everi day and it stay ok clean freak',
#   1),
#  ('swarmichael dude i d love to but i m so hungov feel poopi', 1),
#  ('i m excit that i alreadi found my roomi for next year', 1),
#  ('lilmarshmellow noth gon na watch a movi wive ur si and aisha mayb jojo', 1),
#  ('filou my littl dog', 1),
#  ('realis someth last night good it is to me', 1),
#  ('final in my own bed time for some z s wish i coulda stay at corey s', 1),
#  ('skylerhambi aww i wish i felt bad about that', 1),
#  ('it s not so bad i just lost everyth from novemb of to the present', 1),
#  ('we had bot on our irc channel now onli two', 1),
#  ('did go put in the end and now ha a bad head will i ever learn', 1),
#  ('i don t think i m gon na be abl to handl not see jay leno at everi week night i feel so old meh',
#   1),
#  ('doesnt feel good', 1),
#  ('live laugh love lie learn', 1),
#  ('shontel layn i think ani color would fit your nail but i m sure you know veri well what blend well in your outfit good luck',
#   1),
#  ('the weather is crap bring on summer', 1),
#  ('be stalker again but now i know the circl fun', 1),
#  ('true blood season', 1),
#  ('err got scold by my bro say that i should sleep earli wutda haha yahyah sure i will haha',
#   1),
#  ('it s definit monday today my inbox keep ping i feel import', 1),
#  ('we just got kick off not fair that wa mean', 1),
#  ('morn everyon still feel poorli hope u all have a good day x', 1),
#  ('tomorrow hannah montana the movi i m so excit', 1),
#  ('just bought an yamaha cp piano im so happi right now', 1),
#  ('welshdragon realli have i been that naughti guess i ll have to take my punish then sit sadli on step',
#   1),
#  ('k race today which wa short in follow by a mile recoveri run race wa great though came th',
#   1),
#  ('still stuck in mexico go crazi i wan na go homeeeeeeee to my rooomi', 1),
#  ('go to riversid to take the stupid math test', 1),
#  ('seanmarl be one dress accordingli to the weather great pic u', 1),
#  ('taylor blue amaz i forgot how much i love their music had to pull cd s out no doubt back in cd rotat',
#   1),
#  ('therami are u serious s my god i feel so guilti', 1),
#  ('shanefoxx all sort and everyth jazz latin classic indi rock show tune theme tune ska i m an easi go sort of guy',
#   1),
#  ('jiminthemorn let s just shoot all smoker me be one of the aw peopl', 1),
#  ('weather is not good for launch a hotair balloon fog to the south of the citi rain come down from the north back to bed',
#   1),
#  ('crappi can t make it to warp thi year happi i m go to la', 1),
#  ('just a coupl thought wa bore thi morn', 1),
#  ('sonicreduc that s whi i alway set my expect realli low i hope thing get better',
#   1),
#  ('doubtless ung kaichou wa maid sama', 1),
#  ('kerryhaggard i get that a lot', 1),
#  ('afonin', 1),
#  ('awww maaaaan it a beauti day', 1),
#  ('iamgeoffpop', 1),
#  ('revfri we are still over at my parent hous wait for the birthday dinner to start we won t be there in time',
#   1),
#  ('hollyefronjona so gorgeou i want the album now and taylor realli need a ew one im experienc withdraw symptom',
#   1),
#  ('so weve got metheori down let move on to practis ye', 1),
#  ('nic pic realli wow idk if matt wa disrespect coz i honestli simpli did not have the interest to read hi interview aheheh',
#   1),
#  ('home now all are safe sound amp sleepi and b can clearli alreadi hear much better thank for all the well wish fb',
#   1),
#  ('girlofavalon the video is great but the audio isn t work well for me so i found on youtub alfi is a cute guy love hi portugues',
#   1),
#  ('omgkati i m do it slowli don t wan na be rude i m so sli enjoy walk home today lol',
#   1),
#  ('man i wa so excit to be back at work after be sick for so long but there s noth to do',
#   1),
#  ('paranoia make us do weird thing to the outsid observ', 1),
#  ('realblackwidow ye it is addict', 1),
#  ('need a realli good sleep to get rid of thi headach i ve had all day look forward to church tomorrow hope the rain stop tho',
#   1),
#  ('pinkberri in the citi', 1),
#  ('miss jubile hope i m right', 1),
#  ('drunkdaz but for a moment there i realli thought i saw five', 1),
#  ('jenniesloan couldn t agre more think that s what entic me to ventur into the prime rout with the f',
#   1),
#  ('gloson websit doesn t work for me s', 1),
#  ('taylorcassidi me too but it look awesom', 1),
#  ('i m current bum in the bio lab', 1),
#  ('jamiemarkwhit nice one mate we ll have to meet up next time you are down thi way',
#   1),
#  ('memandark it didn t work', 1),
#  ('stedavi i sure can hello pleas i would tweet in greek but the onli word i know mean dog hope the demo goe great',
#   1),
#  ('thi is quot my m quot hum twitter veri intrest my mak is awsom', 1),
#  ('mulder sculli i wa wait for it to load i thought it wasn t a banner lol but hey it purrtyyi',
#   1),
#  ('deangroom what nowher on central coast ha adsl move north we have it on the north coast don t know how i live without it',
#   1),
#  ('seldom do you get rain in mombasa but when it pour l do complain which is selfish consid major love it me l just love sunshin',
#   1),
#  ('jpgeoffrion by far the best game i play last year i kinda fail as i bought pata a coupl of month ago and haven t touch it',
#   1),
#  ('i still want to buy a ps and if it s onli for hard rain and god of war', 1),
#  ('lelandstrott hey saw your tweet earlier hope you re well', 1),
#  ('onli two more day of final', 1),
#  ('idk what i did to my pinki but it s bother me', 1),
#  ('i just want a sign that will let me know it go to be alright', 1),
#  ('knee hurt again thi morn', 1),
#  ('eeqahja sorri sister the onli one in thi world with both is me izzah is sooo lucki',
#   1),
#  ('is gettin readi for her child develop test', 1),
#  ('anoth long amp busi day work i can t believ i dont have a day off until next saturday',
#   1),
#  ('oooh a night home alon i think he realiz today what i meant when i said i quot like quot him or he realli just want to quot be lazi quot tonight',
#   1),
#  ('off to watch chloe and caden soo happi i havent seen them sinc tuesday stupid tummi flu yay today',
#   1),
#  ('paradylan and pay day is middl of next week', 1),
#  ('freki realli cool my own kate realli look like the real one lt had to uninstal it again though it made my comput reallyyi slow',
#   1),
#  ('sunday morn and i m awak and drink red bull onc again my thought are not as nice as they should be',
#   1),
#  ('averyemma i made it to last night and then i talk lol i suck', 1),
#  ('wulanhandayani', 1),
#  ('mpeleid i didnt see your last night obv i wasnt at the parti today i want so badli to go but i couldnt walk',
#   1),
#  ('kimbarwe yayyyyyyyyy im sooooooo bore work later and my phone got no batteri xo',
#   1),
#  ('drewbering forget what you know', 1),
#  ('roserusso i m sad you re leav today i ll miss you', 1),
#  ('handi have samaritan opposit for those dark day although i cant open the window so quit safe',
#   1),
#  ('sooooo rugbi wa fing awesom sunburnt face guy got st we play a univers team won one lost one good job ladi',
#   1),
#  ('just got back home i watch termin it wa okay hahaha nugget are out', 1),
#  ('at my bff but i didn t get to see him tonight', 1),
#  ('i ve been work on thi silli english project all day it beat math for a while though ugh',
#   1),
#  ('youngrooksworld i m tipsi myself can t let me drive like thi', 1),
#  ('freeoper thank that s awesom', 1),
#  ('angela pk it swanni i know she won t care but it wa a custom for anoth site that would i drew my own hair i think i should',
#   1),
#  ('i feel so bore and feel like my life is meaningless in mani way', 1),
#  ('what an amaz night it s my th birthday', 1),
#  ('day of the ms cancel and no camp in la grang all i want to do is ride', 1),
#  ('trishaforb i hate move hous still unpack from our move a year ago have fun on friday',
#   1),
#  ('good morn all ahhh overcast my favorit weather caus u can either go pant or short suppos be top here in corona',
#   1),
#  ('is at my other job until', 1),
#  ('crosimplemind onli tao in the summer that is not mani', 1),
#  ('erinher i wa abl to chat with donlinn but didn t see you', 1),
#  ('socialgrac happi birthday miss janic', 1),
#  ('sockkpuppett i thought it wa realli well done d and all i bawl', 1),
#  ('oh shit i forgot to eat grumbl grumbl', 1),
#  ('sdpower i glad i could bring back memori i plan to post more pictur later thi week thank',
#   1),
#  ('jaseyalltimelow post name of first pet amp street you grew up on for twitterpornnam',
#   1),
#  ('joulzil just saw ur repli and i love those peep dalla repres', 1),
#  ('just got back from her first visit to the odulio hous', 1),
#  ('i haven t slept in in a long time', 1),
#  ('markhallcc oh then you must hate low caus i hate walmart but alway end up there to get what i need',
#   1),
#  ('kristisayl your dad and i each have daughter name kristi christi we re obvious bright guy',
#   1),
#  ('ki rei lol what it sound like a cute fluffi dinosaur ye dino can now be fluffi',
#   1),
#  ('i am in the car and sad i have to leav the lake', 1),
#  ('get readi to studi geographi how bore is that', 1),
#  ('courtneychesley yesterday when i wa mow the grass i ran over some mint smell soooo good grass make me sneezi tho',
#   1),
#  ('long bore day tire need sleep miss two peopl r amp s', 1),
#  ('fireforc good morn ting again', 1),
#  ('at work wonder when i will lose my job like everyon els', 1),
#  ('too tire have to get readi for work tomorrow now bf want s tv off so no nois when sleep',
#   1),
#  ('tracksforhir oh and thank for the follow', 1),
#  ('watch the squid amp the whale with ben amp emili my cheek are pink from swim so long w o sunscreen',
#   1),
#  ('how did i manag to leav with onli one phone today what the heck am i suppos to do without my blackberri allllllllll day',
#   1),
#  ('blahh i wa woken up but an i m whi do i forget i m sign on sometiim', 1),
#  ('i found the perfect local arcad about min www gamegalaxyarcad com arcad',
#   1),
#  ('xxxxbettyxxxx ohhhh i m sure it didn t look that bad', 1),
#  ('renedepaula silencio no twitter quot continu partial attent quot', 1),
#  ('veganhop in that case count me in woo dessert are my weak', 1),
#  ('poor zoey wa scare in the car i felt bad for her luveyouzoey', 1),
#  ('lampshadejungl wow sound interest', 1),
#  ('get readi for bed got to get up am', 1),
#  ('happi monday everyon i had a great weekend upstat ny hope you ll have a great week',
#   1),
#  ('vicioustrish awwww my doggi doe that too', 1),
#  ('lefthandedsnail not enough space in word for quot race through her quot',
#   1),
#  ('djxklusiv there someth in my eye ouchi and noon awak at my crib to help me',
#   1),
#  ('tweeti s shortcut for new tweet and the main window mean i pretti much never touch the mous anymor quicksilv love',
#   1),
#  ('ann brand found it but have no time to read it', 1),
#  ('i am sooo over sneez i ve got a feel that the cleaner on the weekend use someth i m allerg to monday are not good for me',
#   1),
#  ('paramoreband ive not dy it iv got red hair anyway it just not as vibrant and i like josh',
#   1),
#  ('also i think i may have tynosynov', 1),
#  ('work', 1),
#  ('colorblindfish oh my gosh everyon is talk about the stage got me so excit day to go',
#   1),
#  ('watch the sandlot', 1),
#  ('melli a take to you to the greenhil s im like minut from there but an or take you to the playbarn okok x',
#   1),
#  ('hey i just came back from darien lake it wa fun but the least fun wa lose my mom phone in the thruway',
#   1),
#  ('omg i want to cri i wa put on hold to win the britney ticket all kidd had to do wa pick my phone line and he didn t',
#   1),
#  ('i wish internet speed here wa more like drive hast here wreckless unfortun it s stop and go surf at kbp',
#   1),
#  ('hmmmm and not especi impress', 1),
#  ('spent the whole shift whilst at my comput stare at bag of haribo arghhhh tri to avoid the sugar rush',
#   1),
#  ('buuuuuuut i m go to continu read new moon caus i love edward gosh i need to find me one of him now that would be amaz lt',
#   1),
#  ('i thought it wa overr and i just realiz it s not', 1),
#  ('you ve alway been thi way sinc high school flirtaci and quit loud i miss bust best band ever',
#   1),
#  ('but i lost', 1),
#  ('i don t like do assign that i don t understand', 1),
#  ('paigey omggg i said that onc stop lol i just said it cuz i beat u in basketbal',
#   1),
#  ('mulder sculli hi pet', 1),
#  ('bailey ff it s harsh time appli for like job and not heard back from one of them gayysss',
#   1),
#  ('lukepritch whi the other don t have twitter want anoth conert shit', 1),
#  ('idolfanat good i m glad lol ya isn t it cute it a littl chibi adam', 1),
#  ('thestafford well michel have a fabul saturday i am off to do what i love best clean hous ugh',
#   1),
#  ('found the best amp for onli definit buy it gili is the best salesman becaus it is her or at least it wa',
#   1),
#  ('is b down', 1),
#  ('just finish of paper due thi week faboosh life right now hell but im soooo happi my boo visit me',
#   1),
#  ('awww man patti b got vote off i thought she wa the underdog and wa gon na win thi thing',
#   1),
#  ('just got home from work out at the gym and then went to the spa in my apart complex relax',
#   1),
#  ('pikach i love taylor swift let s agre to disagre on miley but be taylor fan togeth haha',
#   1),
#  ('i wish my neighbor s internet would cut back on', 1),
#  ('trixi sure did just hope the good weather stay with us d', 1),
#  ('sheraan thank ani app that actual give time instead of wast it i d pay for those',
#   1),
#  ('joshramsay i wan na go on the th but i cant u guyz shud hit up woodbin beach after',
#   1),
#  ('nockey haha im not lie you are lol', 1),
#  ('lemonchild what s the matter chickade', 1),
#  ('bexiclepop are you not go now either then', 1),
#  ('steve the love of my life goodnight', 1),
#  ('kimmikennedi how u enjoy it everi els i know saw it say the same', 1),
#  ('e betht we re all just amaz you re tweet about articl right about now tek',
#   1),
#  ('mlexiehayden the had some of the best group diddi pop just kill em', 1),
#  ('uniqueguitarist ye they re the best', 1),
#  ('gordonjai the end minut ago from txt', 1),
#  ('morn all just walk down to get a coffe shouldv drove down i can t feel my face with the wind',
#   1),
#  ('i m back in school it suck', 1),
#  ('oh what a weekend and it s still not over', 1),
#  ('doomdoom i saw that on jona too but where is that line from co i ve heard of it my i can t rememb where',
#   1),
#  ('found a good song on spotifi', 1),
#  ('aurihunt yea i watch it everytim it come on tv i cant pick my fav part though',
#   1),
#  ('papercak sorri it broke', 1),
#  ('in the rain with pj amir ant almir kristin amp mike love the raain', 1),
#  ('amanda ratliff sorri to hear that i am hope my insomnia is just temporari it s been drive me nut',
#   1),
#  ('toastcommun ikr him and francoi better be come back', 1),
#  ('beatbutcha nah im pack', 1),
#  ('zacxor schick mir mal pl ne email an pr f ne googlemail ty', 1),
#  ('naughtymutt violetbak we have had our first gogo base argument could onli find one bag',
#   1),
#  ('time to leav my mountain back to bama we go', 1),
#  ('we just lost in extra inning now i have to recharg my back with some mountain dew',
#   1),
#  ('goodnght tweeti who don t pay attent to anyth i write byeeeeeeeeee', 1),
#  ('damn rct i m so tire ugh i m so down right now i need my favorit girl', 1),
#  ('i hope there won t be complic with the fall i had just now alreadi the pain is intensifi',
#   1),
#  ('brianrandel work on your execut platinum fflyer statu for the year eh', 1),
#  ('i want jbro to comment me', 1),
#  ('alicedoherti hope your alright work is gash xx', 1),
#  ('just got home stop by aj s', 1),
#  ('now i m watch the tonight show jay leno s last show', 1),
#  ('gahdess goodnight i hate it that i don t get a warn beep', 1),
#  ('i went to the red game yesterday and i had great seat row from the red dugout to bad they lost',
#   1),
#  ('want to go to ddo had such a wonder time there', 1),
#  ('goodnight goonight', 1),
#  ('jvon you still did not answer my question where is md i am updat my verizon plan did not get a tweet today',
#   1),
#  ('toodel off to bed now to watch a bit of tv almost look forward to go to school tomorrow nighti night my wee pumpkin head',
#   1),
#  ('madsxi thnx ashleyl it been good ur', 1),
#  ('yay my photo show up now', 1),
#  ('adamtylerx hey adam thanx for warn me about the poser pleas make sure all the other guy know it not me thanx again hunn ur awsom',
#   1),
#  ('love the new mother s day snl digit short mother lover oohhhh corny', 1),
#  ('lol ok ok dank is not the equival of drank fuck', 1),
#  ('redmummi oh bet willtompsett get to be on the elit team he s alway better than me',
#   1),
#  ('iamhaitianfresh twitter heard from you yesterday befor i did', 1),
#  ('is realli realli sad', 1),
#  ('aneehan thnk fr th mmr', 1),
#  ('i didn t get card to drink thi sadden me', 1),
#  ('miss hi em', 1),
#  ('studi for final for about hour vivans is my new best friend thank alex', 1),
#  ('wtfjay night hope you get more rest thi time', 1),
#  ('first post on twitter', 1),
#  ('man i suck at draw ani kind of icon that involv peopl', 1),
#  ('the toni of the reviv of west side stori holi shit he s unbeliev delici',
#   1),
#  ('at home i think im go to go swim today', 1),
#  ('klstewart not all of them up here they are gner staff in new uniform and they are realli help',
#   1),
#  ('fill the time befor i have to go to work', 1),
#  ('is it not enough that i bought the cd on yoga do i realli have to do it everyday',
#   1),
#  ('darkid es el segundo blog el otro es mylittlebabi com mx', 1),
#  ('hortovanyi yup like to be shite but we ll see', 1),
#  ('say somethin to their twit', 1),
#  ('i loooov the new jordin spark song amp i cant wait to hear who is in the final',
#   1),
#  ('papadimitri i did too but it s a wonder present to the volunt and speaker tedxtokyo',
#   1),
#  ('waltermosley pleas help pass thi on for the kardashian', 1),
#  ('ok lunch i m up for it so i m gona go get me a jambon', 1),
#  ('whatyoudeserv hahaha do it you ll have a blast', 1),
#  ('i m bleed and carey gone but i m watch anim so yay plu i have mint', 1),
#  ('lauraechild ohhhh but i will be ever so sad and you know you need to talk to me atleast onc aday',
#   1),
#  ('flight delay out of ny rerout flight to get home in a center seat oh well at least i m go home',
#   1),
#  ('britain s got talent is make me cri', 1),
#  ('i dont like get so excit about job bc i dont want it to end up suck haha play time',
#   1),
#  ('teddi grow stach for winter', 1),
#  ('the bu is hot', 1),
#  ('i forgot my sunglass not to happi about the sunshin today', 1),
#  ('i don t know how i did it', 1),
#  ('whi doe everyth i have around here get eaten', 1),
#  ('good that river in indo sure look nasti i d recommend swim in bass lake ca prn',
#   1),
#  ('eye redder than ever f k pollen', 1),
#  ('camillaaax no but plenti of cloud look like it may tri', 1),
#  ('i have so much to do after school', 1),
#  ('tripl a how am i soft cuz i don t wan na talk about your ld sex life nasti ass talk about your new one the one that s bandana less',
#   1),
#  ('ashleyizc l lookin right glad i did see lol u a mess', 1),
#  ('in bedb up earli tomorrow to shop in provincetown last day in cape cod', 1),
#  ('i m back ooh it wa so cool again', 1),
#  ('arimatheia sure', 1),
#  ('just got home from one hour of run puh', 1),
#  ('meet my niec for the first time today', 1),
#  ('alick zanidia ye he is veri hot inde oli is a mean guy i think tom wear contact len but whocar they re both dreami',
#   1),
#  ('shiggybythebay foster s wa one of the best cartoon ever i love it i wish it still show on tv it made me laugh so hard',
#   1),
#  ('eat a bbq sandwich yummmmmmmmmmm', 1),
#  ('jordanknight wish i sould be ani where close to your show pl come to south america',
#   1),
#  ('darraghdoyl wahoo veri best of luck what a fab day to do it on too', 1),
#  ('im in sooooo much pain someon pleas get me out of here and then i have to drive home thi will be an event drive',
#   1),
#  ('carlo miguel you re a fan of wwe me too', 1),
#  ('mom brought us a gallon of ice cream yum', 1),
#  ('ah so confus thi is the weirdest site', 1),
#  ('want to whack someon in the head i feel numb', 1),
#  ('simplyu yep watch it it s a back to back season ender e ep', 1),
#  ('free onlin tool for get more info about pictur www jpginfo com check it out',
#   1),
#  ('gon na be late for work i think uh oh breakfast in the car', 1),
#  ('diego my meebo ha gone bonker i can t see ani onlin friend', 1),
#  ('anyon els wake up earli tomorrow for new iphon guess i ll be get in line around glad the appl store is minut away',
#   1),
#  ('first time in week that i actual studi all day about the air franc flight so sad and scari',
#   1),
#  ('carriele oh did you go all the way back home for your laptop', 1),
#  ('thisisjest dammit i fell asleep', 1),
#  ('gma tell mellodi that unbrok is great someon final made financ entertain',
#   1),
#  ('mrshoskin ooh i ve got that dvd never got around to watch it is it ani good',
#   1),
#  ('drat tri to share itun lib b w window and mac and lost it complet time to re rate everyth itun',
#   1),
#  ('my feet hurt like crazi and i m serious exhaust', 1),
#  ('drew thompson from we the king look mega like mike carden', 1),
#  ('glass half full now if i win ur red tote purs giveaway i will twist my arm and do open it',
#   1),
#  ('shay mari', 1),
#  ('argh alexand the cat have second asthma attack of the day whi oh whi did we switch the litter vet on monday',
#   1),
#  ('sarahchat o did u see jb is go back to dalla im sad', 1),
#  ('is saigon intern airport await our pal flight back home', 1),
#  ('himynameisros yeah it wa and i went but didnt get in but it life ha', 1),
#  ('simon goodluck i ve heard the aw lectur alreadi but each time i like it more',
#   1),
#  ('rain and feel crappi', 1),
#  ('brandisco yup you ve got me figur out lol and now so doe the rest of the world',
#   1),
#  ('just got home from the beach and sadli enough i left my celli there i am out of contact with the outsid for go on hour',
#   1),
#  ('is watch the last temptat of christ drink sangria and is veri all by myself',
#   1),
#  ('annhawkin thank', 1),
#  ('haha chewi is walkin with mee', 1),
#  ('agreb on a sunday', 1),
#  ('revmem yup wa say that i surprisingli enjoy it expect someth horribl dri but it wa actual pretti entertain to me',
#   1),
#  ('songsstuck okay i can die now', 1),
#  ('joelmadden i hav to wait too', 1),
#  ('foodurchin never use to have to do thi and use to get load of flower and courgett but last year crap',
#   1),
#  ('breatheband ahhh so excit i wa jammin to classifi in the car today and realiz how much i wantcha new stuffff',
#   1),
#  ('friday hell yea', 1),
#  ('at dora uriel melodi new apart best part is it s right across the street',
#   1),
#  ('meginaregentina stori of my life right now babe come home and we can wallow in our sorrow togeth',
#   1),
#  ('just finish my break back off to work for hour minut and then hometim love you jase',
#   1),
#  ('so sadli n got shock see my babi littl si got violenc from her bf', 1),
#  ('i d forgotten how much fun it wa to watch transform and gundam wing gon na start on shutter island now',
#   1),
#  ('soniachoquett oh snap i wish i knew i would have love to attend i just start tap into you as a resourc love the card',
#   1),
#  ('possibl just miss out on free glasto ticket becaus it s so last minut and i have stuff organis gut again',
#   1),
#  ('penguinjanet i m tri to decid between a new iphon or a blackberri', 1),
#  ('is sad that she final had to turn the air condit on home', 1),
#  ('taeboqueen need a time out but i m back thank for the love good to be miss girl xo',
#   1),
#  ('franzia sooo jealou tri not to sing along too much dure the show', 1),
#  ('just got home form the parti had an awesom time laugh at my brother do the quot macarena quot lol',
#   1),
#  ('whi won t my pictur show oh well i ll get to see my quot caro kellan quot on tv tonight with quot sexi is a warm rob quot and t',
#   1),
#  ('i ve put twitter in my blog cool', 1),
#  ('i can t sleep i wish nicki didn t go to bed', 1),
#  ('lofnotc now that we re get to be a trend i m get burnt out', 1),
#  ('nell xo not been there sinc april lamb cow next to cuz s hse amp mini hors',
#   1),
#  ('holi shit it way too fuck earlyyi howeverrrr tlfg efff yaaaaa', 1),
#  ('the breez feel nice night everyone', 1),
#  ('still awak wonder whi', 1),
#  ('sweynh robinmatthewfri she still look good actual', 1),
#  ('danluvisiart whi are you never on msn anymor i am here wait to talk to you and bam you are gone',
#   1),
#  ('and i m go mad my gym shoe are in storag i plan to get back into my run routin tonit so much for that',
#   1),
#  ('zachhump wassup i m chillllllllll', 1),
#  ('take a break at practic i love her so much', 1),
#  ('went to lake winni with michael jessica toni mandi and tessah it wa fun',
#   1),
#  ('bleumuz thank', 1),
#  ('jenmaselli is she sneak out and go to rave in the middl of the night or do strang littl emo boy come lurk around for her',
#   1),
#  ('jusadbella i stand by my franki love and now i realli don t know who to back',
#   1),
#  ('last night wa realli good', 1),
#  ('had solid hour today woke up ate lunch and ate frozen great appl thing with milk while watch stardust now my head hurt',
#   1),
#  ('sunday confess on behalf of me and lebron the laker are the best team in the nba thi year man it hurt to say that',
#   1),
#  ('go to sleep after two disc of one tree hill way too much cri in one night',
#   1),
#  ('linehan lol oh right don t worri we won t make you the offici tweeter upper organis hope the hangov is better later',
#   1),
#  ('facebook function for dsi cool i m like thi user gener segment oh wait she said no more on that',
#   1),
#  ('ad new collag sheet', 1),
#  ('smileyladi see the blue sky is tortur and then don t u know it come wkend it ll rain',
#   1),
#  ('if your at britney as well as me tonight have fun i m in the loung', 1),
#  ('jasonniad shut up ps chri johnson wa walk around with a cane yesterday i ask him if he wa take class but he didn t get it',
#   1),
#  ('regent day amp i aint gon lie im type worri lmao wi h me luck doe my twigga s',
#   1),
#  ('bonfir i want a cooki', 1),
#  ('codysio the of us are still wait', 1),
#  ('sunday cheer for the retweet troystith lunabe art', 1),
#  ('bed time back to realiti', 1),
#  ('jhillstephen i bought m amp m s at the store today but i can not find the cherri one you keep rave about',
#   1),
#  ('thank god it s friday i m jealou of my boyfriend go to taho', 1),
#  ('texa lost the cw', 1),
#  ('wish there wa celtic bull game today', 1),
#  ('flircr total no way to go but up from there and there s alway snuggl with movi sorri guy',
#   1),
#  ('captainparish sweet and the clan grow', 1),
#  ('didn t make it to comic con due to car troubl so lame upshot got my car back just about readi to be on the road again',
#   1),
#  ('jilliankeen nope it wa out in the countri at night so def not me lol goin home tomarrow yay',
#   1),
#  ('total engin run life is hour and minut and second of total fun i enjoy the ecu read out haha lotu exig',
#   1),
#  ('i miss my boyfriend terribl and i want thi rain shitti weather to go away',
#   1),
#  ('watch andrew kennedi standup on comedi central quot it bloodi brilliant quot',
#   1),
#  ('out in hallendal beach sit next to a beauti pool that is beachsid becaus lightn is permit no one to enter it',
#   1),
#  ('good morn final the weekend my goal listen to music play video game and sleep',
#   1),
#  ('bryangwin siahwalk natepwelch matti clark u guy will not guess wht i just saw u in ap whi didnt i see thi befor',
#   1),
#  ('awwwww man my tcbi is damn near gone n i want anutha one tear what am i gon na do it onli in stamford',
#   1),
#  ('parti on the lawn', 1),
#  ('addict to drama i have to stop watch them continu make self tire and not do thing have to do',
#   1),
#  ('feltbeat congratzz your site deserv it keep up the good work and sorri about the post i did misha i didnt know xx',
#   1),
#  ('i just watch a woman lose her husband on tv wonder that make me feel a whole lot better',
#   1),
#  ('charltonbrook well said there s word that nick griffin ha won hi seat too',
#   1),
#  ('i miss summer', 1),
#  ('lilylauren well i ring mine but the whole batteri gone flat thing is a problem iphon isn t go to fix that',
#   1),
#  ('brokenipod guitar hero rock even tho i haven t play it in age l i miss it stoopid revis',
#   1),
#  ('wow opera unit is one of the most discuss stuff in twitter today', 1),
#  ('cleaninggirl my sympathi for your friend sausag must save the world', 1),
#  ('don t you hate wake up and suddenli realiz you had a bad dream dure the night',
#   1),
#  ('last day of highschool', 1),
#  ('ye twtvite akljulytweetup noth like be organis well in advanc', 1),
#  ('attack of the allergi', 1),
#  ('is sad that she ha been so freakin busi late', 1),
#  ('better wrap thi up now hope you guy are have an ohsom summer', 1),
#  ('off to work it s onli a half day', 1),
#  ('tri to decid whether to accept flat or not horribl decis to make', 1),
#  ('hahaha math exam wa shit', 1),
#  ('have a lazi friday off school til thursday the th', 1),
#  ('princess sassi hell and long it still winter here i have on a freakin flannel robe',
#   1),
#  ('nicolaherbert goggul bad busi day today xx', 1),
#  ('carlo just got home from prom last night', 1),
#  ('i realli wish i could find out what s caus my stomach issu i m so sick of the pain',
#   1),
#  ('mpinheir yah it wa wick', 1),
#  ('i have the cutest niec ever', 1),
#  ('louisec nagkaassembl kahapon si t feni mismo nagsabi pagnakitaan icconfisc ta di na ibabalik kahit ano maski commut tsk',
#   1),
#  ('thisisbre yeah i thought it would get bigger but it wa fine it wa small noth fell everyth s fine',
#   1),
#  ('listen to therealsavannah on radio disney', 1),
#  ('ok so i m a lil happier now i hope i fixd my email hope they weren t hack although it seem realli suspici',
#   1),
#  ('at work so i ll have to chat later', 1),
#  ('skittlelipsmack i know suck i didn t see you dismiss', 1),
#  ('mnrmg omg so hot i could go on and on about those two doc but i ll spare you they are just so f abl k i m done',
#   1),
#  ('julialight one paper and then i m free', 1),
#  ('sugarwilla i can live with that oh ye don t drink the water', 1),
#  ('myagxxx i see u made it don t hurt em too bad out there they alreadi out of the playoff lmfao',
#   1),
#  ('comiendo froot loop mientra veo grey s anatomi', 1),
#  ('ugh', 1),
#  ('dangriffey in franc it wa last friday and also the come one we are work',
#   1),
#  ('bantu actual i wa refer to my ass in those candi pant', 1),
#  ('quot you say what you want to say your s are drop of rain your is your credit card and your currenc is your quot',
#   1),
#  ('shropshirepixi have to come to the ironbridg ale and folk rock festiv much pixi fun to be had',
#   1),
#  ('officialcharic wew how are you', 1),
#  ('well no more school until the first day of school in septemb that is', 1),
#  ('still upset at not be a lotteri winner again no fair', 1),
#  ('itun store disabl my account becaus i have no prove of my bill address sad not more song movi purchas',
#   1),
#  ('school for me will be finish when i read book', 1),
#  ('the cd haven t come out in bulgaria yet i can t wait wish they were faster',
#   1),
#  ('about to cycl within thi quarri on shipley glen near baildon moor befor head back through the wood',
#   1),
#  ('tessthetravel you ll start to pick up sentenc structur and common word just be determin',
#   1),
#  ('lindzeynichol thank lindzey thank', 1),
#  ('oneclassyliz mlb score that s fantast i can actual pictur that', 1),
#  ('iggi hehe well i think most ppl with iphon think the same way whi the user name chang',
#   1),
#  ('our current canon pocket camera doesn t take sdhc so the eye fi sit unus',
#   1),
#  ('imma go to sleep realli earli tonight i m sooo freakin tiiiiiiiiiiiiiiiiir',
#   1),
#  ('marybozigian ah but don t forget about my good friend karma i ll send her their way right now',
#   1),
#  ('i haven t been on thi ina while so though i would come type someth today had a math exam c wa amazingli hard so yeah good time',
#   1),
#  ('sanasaleem congratul', 1),
#  ('angela oh i know whi is csi so much more accept whenev i watch csi i m like yeah yeah that s how it happen but whi',
#   1),
#  ('mitchelmusso i went to go get your album but they didn t have it yet so i m gon na got get it tomorrow i hope',
#   1),
#  ('just had to get tissur form the school toilet becaus mine ran out from hayfev rape it s all rough',
#   1),
#  ('is go to watch movi today it is rain', 1),
#  ('i don t wan na wake up', 1),
#  ('smjkxsnoopi that suck good see ya last night tho for onc jashik you have fun i got sooo shwast face',
#   1),
#  ('im final go to sleep and i have to get up in and a half hour', 1),
#  ('jonathanrknight i still think you should tri it do it do it lol i want to see photograph evid though',
#   1),
#  ('just talk to my dad i wish i could see him today', 1),
#  ('yay got to c old friend ahh memori', 1),
# ...
#   1),
#  ('jam metro station i miss the famili', 1),
#  ('bed time nighti nigh xx', 1),
#  ('comcastbil now my connect drop liter a dozen time a day', 1),
#  ('bethasaurr hug', 1),
#  ('you re welcom kati you don t thank someon if it someth they want to do i want to amp r burger ain t got shit on meh',
#   1),
#  ('namii omg envelop and stamp i forgot to give them to you', 1),
#  ('oh man had a great day woke up to beer bottl all over the hous chill with the besti all day shower time',
#   1),
#  ('my babi girl is sick', 1),
#  ('billingtonart ye noth like a sunni day in england i can almost hear vaughn william enjoy the day',
#   1),
#  ('veri disappoint christma is ruin preorder my iphon from stupid att over a week ago will not get for to week more',
#   1),
#  ('elyss haleeb you guy are soooo just jealou caus they won go laker', 1),
#  ('markhawksworth cheer', 1),
#  ('turkeyburkey just do my job', 1),
#  ('stop feel so sorri for yourself apri there are peopl who got a wors side of thi',
#   1),
#  ('liverpoolfan i can t i must find some food', 1),
#  ('no juli phone die', 1),
#  ('iammandurr i knowwww omgsh tour will not be the same without them', 1),
#  ('mottel ha you do have shame', 1),
#  ('mgiraudoffici i wish i had a convert have fun matti', 1),
#  ('madhatt love your profil background', 1),
#  ('ddlovato sorri but i tri to vote but i m from spain and i m unabl to vote',
#   1),
#  ('argh just had posti deliv back a v urgent suppli parcel for my dad which had sent to usa week back as address label had smudg',
#   1),
#  ('i can t decid if i feel sssick or extrem tire not good anyhow amp i m due to take a hayfev tablet but i don t wan na move',
#   1),
#  ('comfypaw hahaha well i guess i will have to make do with the trick he alreadi know',
#   1),
#  ('cook asparagu with potato and salmon', 1),
#  ('okay i cheat a lil bit that a pictur of a pictur', 1),
#  ('it s so dark alreadi', 1),
#  ('whi am i still awak', 1),
#  ('urgh up shower hair done breakfast time now i think', 1),
#  ('wossi doesn t the wife get fed at all how is she is she better after all your nurs effort have a nice sunday',
#   1),
#  ('got to walk mile home now', 1),
#  ('vengeanc congratul whi you can t go to birmingham babi', 1),
#  ('i wan na watch transform but i sud probabl watch the st one first', 1),
#  ('go to watch depotivo de la coru a s match', 1),
#  ('hang with my cousin megi wait for news on kri br', 1),
#  ('i miss my phone', 1),
#  ('code a cool css to format the php twitter script', 1),
#  ('ameliaastuti hohoho let s danc togeth then', 1),
#  ('anim sorri i didn t realiz i would be miss', 1),
#  ('it feel so good to be back at home for a week go to dave matthew tomorrow night w gabe',
#   1),
#  ('ugh what a bore day', 1),
#  ('ayomelli usual when a chick tell me her tonsil are swollen i get super excit in your case i just hope you get sweeeell',
#   1),
#  ('merewichdabitch i ve been unlock for decad now just not lucki never have been gottta make my own luck and that involv',
#   1),
#  ('is tri to figur out thi gay littl site tee hee', 1),
#  ('checksarahout im fed up i have to work and dont want to', 1),
#  ('logomotivemik yeah join us i suck mayb you ll give michel a run for it', 1),
#  ('brittthompson that becaus he wa dream about me', 1),
#  ('mzkellybabi yeh like who s ur all time fav music artist sorri for be vagu',
#   1),
#  ('christyyyjoy that wa funni', 1),
#  ('lareinasantiago yeee haha good luck to us may we have adam lambert in our dream hahaha',
#   1),
#  ('philipglass in hour so excit', 1),
#  ('i m not watch that show call news ever again as byron said quot knowledg is sorrow quot don t mind me major literatur exam morrow',
#   1),
#  ('i prefer thi over kid pokemon rap xd pleas ignor the sad attempt to make a video pic unrel',
#   1),
#  ('so guy at thi parti there is a q amp a what question are we gon na ask i say we come up with some and all of us say them',
#   1),
#  ('i had an awesom time at the no doubt paramor concert too bad we got there too late and miss paramor mayb next time',
#   1),
#  ('quiero ver transform the propos y up', 1),
#  ('ringleaderr ahahaa i live like block away from the americana and yet i didn t even get to see fred hahaha',
#   1),
#  ('so my cat threw up on my bed and the boy pj s and on top of that i bleach my quot i dream of edward cullen quot shirt sniff sniff',
#   1),
#  ('no class for day becaus of typhoon feria', 1),
#  ('snpsalt haha you sooooooo silli', 1),
#  ('famili dinner now how did i get volunt to draw a visio draw for my mother in law krissi hehe fb',
#   1),
#  ('kay bak coursework at loik am in da morn nice huh gt twitetrakd come on r get di finish with amp givem teachaz a shokoderlyf',
#   1),
#  ('williambaobean ye it seem that wordpress com even with your domain is block the best is probabl to host it yourself',
#   1),
#  ('dinner menu with these guy soto kaki sapi bakwan malang tahu telor ayam bakar madu swike sate babi bakut bakar yummi',
#   1),
#  ('bore and sick not fun', 1),
#  ('cjmgrafx home phone not work not sure what verizon did thi time', 1),
#  ('tf ha updat but it way to late to play look like i ll be spi and snipe my heart out tomorrow',
#   1),
#  ('have a terribl headach right now', 1),
#  ('jodymoon i can do a great purr prrrrrrrrrrrrrr see', 1),
#  ('man zac efron look hott', 1),
#  ('do you ever just think to yourself im an arsehol caus tht what im thinkin right now',
#   1),
#  ('i m onlin and readi to talk repli meeee', 1),
#  ('wethetravi unti amp not in oklahoma', 1),
#  ('when will thi person realiz that it s alway been the same it never chang i guess truth realli hurt',
#   1),
#  ('just found out my nan is in hospit', 1),
#  ('doublel i love she s all that i am about to watch she s the man sorri you got the lone blue',
#   1),
#  ('ashymon lmfao that wa so funni how is he still aliv lmao when gil found him he look half dead he s soo hardcor lt',
#   1),
#  ('wishin my babe wa here wit me and not in iraq rite now', 1),
#  ('hot omgsh numberonesmashhit aw man i didnt listen tonight oh look ti still on aargh but gg ok i ll listen to the song moz',
#   1),
#  ('tommcfli you realli don t want to be back at home atm it is rain ha been all day',
#   1),
#  ('lennytoup honestli i don t think you could have paid me a bigger compliment you re all good',
#   1),
#  ('tastemyink most likelyy just need to save the money and practic my ass off',
#   1),
#  ('bradiewebbstack heyyy can you play electr drum well that wa random but it would be cool if you did',
#   1),
#  ('sean even expect it i m just a tender heart', 1),
#  ('is watch dinner imposs', 1),
#  ('i want thi one amp i will hug him and squeez him and love him forev', 1),
#  ('kimoraleesimmon congratul your first son the girl must be so excit to have a brother',
#   1),
#  ('chelseaheath yeah goodby niagara fall wed okslang i wa lucki enough to wit load of sceneri in sf ani polic updat',
#   1),
#  ('hiddeninthesand true but new tallyhal album feel so far away', 1),
#  ('sick n cold but ha a new jumper', 1),
#  ('jayboo realli i didn t get it', 1),
#  ('imag from today s commerci shoot cosmet dentistri headshot thank jenni ingo amp meghann',
#   1),
#  ('fayen waaa you lost it all n broke ksian eh hope i can lend u some money',
#   1),
#  ('window argh had i known someth wa go on today i might ve stay longer crash hard yesterday eve amp didn t make it to parti',
#   1),
#  ('ha final got someth to wear woohoo cant wait to go out in abit xxxx', 1),
#  ('christft love the new song it so deep', 1),
#  ('mikekennedi when i passbi toronto will keep you in mind hello', 1),
#  ('taral ani recommend i ve got eztv onli', 1),
#  ('skyetownsend hey', 1),
#  ('jdyat that s total go to leav a wick scar think of the war stori you could tell ouch seriou note hope it heal quick',
#   1),
#  ('martykju i am also go shop with my girlfriend', 1),
#  ('hatfield mine is shot too i m squeak', 1),
#  ('i hate shift but got ta do no other option', 1),
#  ('raini sunday do laundri and finish up sketch might even do my nail', 1),
#  ('bradkearney now the world get to see our convers about hotdog mac amp chees and your bro i m sure they re better for it too',
#   1),
#  ('rota platformnin but i realli want cake and hufflemuffin hufflepuff', 1),
#  ('struggl with css atm', 1),
#  ('right behind uestlov', 1),
#  ('damana sad too am home studi for stoopid exam', 1),
#  ('brenddaxo i hope u didn t repli', 1),
#  ('mmmm cold rock doubl choc ice cream with marshmellow and tim tam so good',
#   1),
#  ('sharastrand a hot shower and some nap alway doe the trick for me to relax anytim of the day hope thi help',
#   1),
#  ('watch twilight for the bajillionth time and eat snicker mmm nougatoc', 1),
#  ('symphnysldr i met you yesterday at the grove thank you for be so sweet it made my day thank you lt',
#   1),
#  ('lifeinflux it wa the shark not dori who sid thi geez tri to pay attent', 1),
#  ('mickyyoochun lmao oh ffa i want to join in but i got work to do waaaaah',
#   1),
#  ('amyhoy yeah may not even be arial', 1),
#  ('back from london babi one looong meet and no time for shop or sight see',
#   1),
#  ('forthejok ye you should have', 1),
#  ('alemannia aachen fsv frankfurt yeah', 1),
#  ('whi ye i am follow tom felton hahaha ah it s not funni without niki here',
#   1),
#  ('found new wasabi pea pusher for my habit big bag', 1),
#  ('candiceshelley that s not a problem thank for ask', 1),
#  ('whi won t the interlac go away for the lose', 1),
#  ('yay back home from the mall man i m tire', 1),
#  ('follow d day red wing pen hondura penguin detroit jay z phish palm pre pittsburgh',
#   1),
#  ('ayschuck welcom back wa wonder what happen to ya your niec is a cuti', 1),
#  ('tarek so how much fun is ny so far i m jealou', 1),
#  ('is about to get some voltag', 1),
#  ('i wish i can copi and past on the iphon itouch', 1),
#  ('whoohoo sew time amp finish block for first quilt', 1),
#  ('loveodt well cindi doesn t have', 1),
#  ('wait for pink panther to start with the lad', 1),
#  ('leslielovexoxo i knowwww so sad for my sexxxxyyi ass dwight i miss u le let hang out sooon',
#   1),
#  ('my littl car is ill', 1),
#  ('i keep get attack by some stupid person with like villag on travian', 1),
#  ('csi printchick nooooo u were soo excit and look fwd to it damn bitch', 1),
#  ('thedu o don t kill your doggi', 1),
#  ('yay for walk on stop sign talk feet and giant footprint team definit won tonight',
#   1),
#  ('head up the park for a picnic not had a chanc to use my picnic basket well backpack sinc i got it as a wed present',
#   1),
#  ('acortez i love both of them i listen to them like everyday', 1),
#  ('i think i got a flu aw shit not a good way to start a holiday', 1),
#  ('thebraysmommi oh no that sound aw', 1),
#  ('grosss feel sick around the hous', 1),
#  ('start to worri work today', 1),
#  ('theatrenut blue and green of cours', 1),
#  ('wait for my steph to come to mine she said quarter to but it s ten to and still no steph go the chippi yay',
#   1),
#  ('snyderman day i ll die by then', 1),
#  ('ctrickett wel if u wud rather go footi than hav a drink on my last day then it fine i wnt mind',
#   1),
#  ('go to the mall again w fl lt', 1),
#  ('omg wii came out with a new version of mike tyson s punch out so excit right now ultim fav old school game',
#   1),
#  ('greyseer hug hehe mayb you should nap at lunch', 1),
#  ('my fone took a fall moment ago', 1),
#  ('awww man thi is crap he seem attract to me phew', 1),
#  ('flaviav lol i wa ju smile at your pic you post earlier', 1),
#  ('is watch quot crush night quot which take a centuri to finish load it wa a riot here thi afternoon lol',
#   1),
#  ('asot anyon els spot me the trancecat see imag that s me mrraaaauwww liek ha seen me',
#   1),
#  ('neevl veri true they are make it realli hard to watch eureka', 1),
#  ('my two littl buddi tonight the smart water and the not so smart water', 1),
#  ('mtv music award', 1),
#  ('excit about my first mother day happi mother day to all my fellow co labor have a bless one',
#   1),
#  ('went out earli thi morn to look at some car couldn t find anyth that wa just perfect',
#   1),
#  ('my teacher assist call in today thi is go to be a long and crazzi day', 1),
#  ('think life realli isn t fair especi when bad thing happen to good peopl',
#   1),
#  ('hehe love it praxilla', 1),
#  ('chrismc see u in a few buddi', 1),
#  ('yep he s eat it the dirti bastard right got ta look busi the last min later y all in out thi bitch lovin ya work',
#   1),
#  ('thi weekend wa great didn t have to do anyth', 1),
#  ('debbi had sign up for yoga class and will be start on thi sun pm tgt with ailin',
#   1),
#  ('katehugh no fun time plan', 1),
#  ('adhyss r u sure how bout the best look male on the planet haha', 1),
#  ('i m not sure it is a possibl idk who go yet cept michael and syd', 1),
#  ('and he sat at the famili tabl at tiger s wed i d hang out with my friend down there too too bad they re on their senior trip',
#   1),
#  ('morn twitterbug i woke wit a quot ciroc quot headach but i m super happi i love life my chicki my trife ass nigga my',
#   1),
#  ('are stuf envelop', 1),
#  ('beautifullos see what we will use one funni one normal but serious im not use a ginger one haha i look happi in lot',
#   1),
#  ('off to the doctor', 1),
#  ('funkylovin i can t see anyth', 1),
#  ('darrenmil ye pleas i m die of swine flu', 1),
#  ('spent a moment in fred astair s shoe today', 1),
#  ('tri to watch dollhous onlin it not work', 1),
#  ('is broke as a joke', 1),
#  ('my arm is sun burnt from leav it out the car window and thi is whi i stay away from the sun everi year tan fail',
#   1),
#  ('finish takinq picszzz for myspac ha new picsz', 1),
#  ('on way back from ace day at dbuc wa up at am after hr sleep amp now just want to doze on train but the seat is so uncomfort',
#   1),
#  ('my boyfriend s go camp i hope the boogi bear doesn t get him', 1),
#  ('i m about to buy myself some new shoe mayb that will brighten up my day',
#   1),
#  ('lozzi now that would be impress back home from fete now', 1),
#  ('davidarchi i also want to see up my friend said it is nice david do you like to read',
#   1),
#  ('i offici know how it feel to be unwant by the person u love', 1),
#  ('nextradrealtym lol thx glad u like it i wa rais to take everi compliment with grace amp style',
#   1),
#  ('bought an onlin market book from sitepointdotcom amp shaynet ws realli help sort out a technic issu hv the book now thank',
#   1),
#  ('benofski patrickod i wa around for the spat and the ensu discuss afterward where mike and leo clear there air friend now',
#   1),
#  ('i like puppi good thing you re veri love and not expect to be perfect', 1),
#  ('darlenevictoria oh i hope you and kenaroth don t have to wait that long either',
#   1),
#  ('stacefac kelli c s in the countri she wa on tv last night and will be on anoth show tonight',
#   1),
#  ('there are thing i want to do but it is to dang hot to even think of do them even insid in the ac haha guess that an excus',
#   1),
#  ('yo sushigirl yay o yo she of sushi like thou hast shone great feat of memori and good tast in the recal of thi small fact',
#   1),
#  ('had a late and delici dinner now relax with the fianc', 1),
#  ('lostininaka turn r amp j into drink game keep you alert talli refer w friend l r',
#   1),
#  ('shinesofli', 1),
#  ('great now my other dog mia is sick and we think it with the same viru', 1),
#  ('my granddad just die', 1),
#  ('greggarbo as long as it s not red bull that stuff is so bad and the amount you all drink worri me greatli as a fan amp futur doctor',
#   1),
#  ('xosar lol yeah all parent think that about their children', 1),
#  ('huu hoh thigolaa ehba uhlhen dho dhuniyeyga u have ps tha let do network gameplay',
#   1),
#  ('and not onli did i get a handmad linen from switzerland with lotu flower on it i got two of the most beauti pictur of lotu ever',
#   1),
#  ('ibeatcancrtwic thank i even wash behind my furri ear you look marvel too',
#   1),
#  ('got a birthday card in the post today belat wish keep the month merri', 1),
#  ('i am look for someth to eat and it am hahaa can you say fatass lmao', 1),
#  ('blakelewi i met you today i wish i could have seen you perform', 1),
#  ('might not have a job after tomorrow o joy', 1),
#  ('stacyharp i think we could find you a job', 1),
#  ('chiewata then must greet him lo', 1),
#  ('mandyyjirouxx i can onli vote for movi and noth el', 1),
#  ...]

# %%
# put all this cleaning together

def re_blob(row):
  return " ".join(row['text_processed'])

sample_df['clean_blob'] = sample_df.apply(re_blob,axis=1)
sample_df.head()
# Out:
#         target          id                          date      flag  \
# 514293       0  2190584004  Tue Jun 16 03:08:48 PDT 2009  NO_QUERY
# 142282       0  1881451988  Fri May 22 04:42:15 PDT 2009  NO_QUERY
# 403727       0  2058252964  Sat Jun 06 14:34:17 PDT 2009  NO_QUERY
# 649503       0  2237307600  Fri Jun 19 05:34:22 PDT 2009  NO_QUERY
# 610789       0  2224301193  Thu Jun 18 09:20:06 PDT 2009  NO_QUERY
#
#                user                                               text  \
# 514293    Vicki_Gee  i miss nikki nu nu already  shes always there ...
# 142282    PatCashin  So I had a dream last night. I  remember a sig...
# 403727  deelectable  @girlyghost ohh poor sickly you   (((hugs)) ho...
# 649503  justinekepa                               it is raining again
# 610789     cmatt007          @MissKeriBaby wish I was in LA right now
#
#                                            text_processed  \
# 514293    [miss, nikki, alreadi, alway, need, thank, xxx]
# 142282  [dream, last, night, rememb, sign, clearli, to...
# 403727  [girlyghost, ohh, poor, sickli, hug, hope, fee...
# 649503                                             [rain]
# 610789                    [misskeribabi, wish, wa, right]
#
#                                                clean_blob
# 514293            miss nikki alreadi alway need thank xxx
# 142282  dream last night rememb sign clearli told get ...
# 403727  girlyghost ohh poor sickli hug hope feel littl...
# 649503                                               rain
# 610789                         misskeribabi wish wa right

# %%
# bow_vect = CountVectorizer(max_features=5000)
# X = bow_vect.fit_transform(sample_df['clean_blob']).toarray()

# # cfdist = ConditionalFreqDist((len(word), word) for word in sample_df)

# %%
# as_df = pd.DataFrame(X,columns=bow_vect.get_feature_names())
# as_df.head()

# %% [markdown]
# ### Building Features
#
# Now let's build the features. Using the top 5,000 words, create a 2-dimensional matrix to record whether each of those words is contained in each document (tweet). Then you also have an output column to indicate whether the sentiment in each tweet is positive. For example, assuming your bag of words has 5 items (`['one', 'two', 'three', 'four', 'five']`) out of 4 documents (`['A', 'B', 'C', 'D']`), your feature set is essentially:
#
# | Doc | one | two | three | four | five | is_positive |
# |---|---|---|---|---|---|---|
# | A | True | False | False | True | False | True |
# | B | False | False | False | True | True | False |
# | C | False | True | False | False | False | True |
# | D | True | False | False | False | True | False|
#
# However, because the `nltk.NaiveBayesClassifier.train` class we will use in the next step does not work with Pandas dataframe, the structure of your feature set should be converted to the Python list looking like below:
#
# ```python
# [
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': False
# 	}, True),
# 	({
# 		'one': False,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': True
# 	}, False),
# 	({
# 		'one': False,
# 		'two': True,
# 		'three': False,
# 		'four': False,
# 		'five': False
# 	}, True),
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': False,
# 		'five': True
# 	}, False)
# ]
# ```
#
# To help you in this step, watch the [following video](https://www.youtube.com/watch?v=-vVskDsHcVc) to learn how to build the feature set with Python and NLTK. The source code in this video can be found [here](https://pythonprogramming.net/words-as-features-nltk-tutorial/).

# %% [markdown]
# [![Building Features](building-features.jpg)](https://www.youtube.com/watch?v=-vVskDsHcVc)

# %%
# your code here

# %%
import nltk
import random
from nltk.corpus import movie_reviews

import nltk
nltk.download('movie_reviews')

# documents = []
# for category in movie_reviews.categories():
#     for fileid in movie_reviews.fileids(category):
#         documents.append(list(movie_reviews.words(fileid)),category)

documents = [(list(movie_reviews.words(fileid)), category)
             for category in movie_reviews.categories()
             for fileid in movie_reviews.fileids(category)]

random.shuffle(documents)

all_words = []

for w in sample_df['clean_blob']:
    all_words.append(w)

all_words = nltk.FreqDist(all_words)
print(all_words.most_common(15))

word_features = list(all_words.keys())[:5000]
# Out:
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\renev\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# [('', 9), ('tire', 9), ('good morn', 9), ('work', 8), ('headach', 8), ('happi mother day', 6), ('good morn everyon', 5), ('tummi ach', 5), ('miss', 4), ('isplay sorri', 4), ('pack', 4), ('back work', 4), ('feel well', 4), ('goodnight', 4), ('noth', 4)]

# %%
def find_features(document):
    words = set(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)

    return features

# %%
print((find_features(movie_reviews.words('neg/cv000_29416.txt'))))
# Out:
# {'miss nikki alreadi alway need thank xxx': False, 'dream last night rememb sign clearli told get job remem sign said': False, 'girlyghost ohh poor sickli hug hope feel littl better soon': False, 'rain': False, 'misskeribabi wish wa right': False, 'nala olowalu still full tummi bread basket': False, 'macintom site seem load must get lot hit': False, 'time sleep hav actual work tmrw': False, 'supercoolkp oxford month': False, 'time cup tea fruit bagel go turn day around': False, 'finish play asshol first time nd place second time st place heh': False, 'final got green bad kept tryna get mix guess green snifflin sneezin': False, 'babimattivi nhaaaiiiiiiiiiii rendi twitter agosto rea hein': False, 'poor kitti make last night lost nurs anoth tonight': False, 'mrpope ok wa cooler search engin launch': False, 'alexalltimelow upset couldnt go': False, 'dev constant rain': False, 'good morn folk last week school woohoo joy joy joy heart spectacular day love extra ram': False, 'even happiest day see sad make sad': False, 'celebr xhumonn sorri asn abl call wa fon koo chuchu miss poo': False, 'troublepandapr use least time kept get rrod shift tha ps': False, 'hmmm wonder plan actual happen today lay bed': False, 'ddlovatofan oh good luck lol': False, 'shine fangirl squee': False, 'ok aoif goin mad hate twitter think sad sad thing peop hu live wors gaa someon callin gaaa': False, 'ugh feel like death warm us sick bueno': False, 'repair': False, 'cristayyy wan see misss youuuu boooo': False, 'eat chocol bout watch dr miss jacob alreadi': False, 'hey younglo showin luv nothin back show donna luv young tv live gt': False, 'pushplaynick quot grandpa ice chest beef quot georg lopez rulesss': False, 'finish homework made final board call sprint plane last even get eat mcd': False, 'gettin readi cupcak ditch cuzin fo sooooo betta make wurth': False, 'heaven earth new seem': False, 'ever trust structur integr roller coaster henc ride': False, 'seren vomit four day keep ani liquid': False, 'phoenixritu thn hv anoth option home': False, 'kimkardashian get readi mtv movi award see': False, 'jason mccartney absolut legend role model': False, 'feel like cr p today bark like hayfev start groan': False, 'annzoo said wa weird read': False, 'drummrboy': False, 'think someon shart themselv train': False, 'finger like prune waaaaa hate feel feel powderi weird ughh': False, 'movi gon see': False, 'go fail math level tomorrow': False, 'nikker need invent love potion dip cupid arrow shove deep right buttock': False, 'hawleydawley sorri': False, 'krystynzilla honestli amaz thank': False, 'richardwatkinsj get mix think normal well hope': False, 'yeah physio wa crap still month away ani form real physic activ couldnt even straignthen leg': False, 'nice sunni day today sun chair storag gon back garden stereo good book glass wine': False, 'go bed': False, 'sharmain awww promblem dear hate': False, 'sorri tweepl still feel pretti miser tweet': False, 'got go prescript diaper rash cream run afternoon poor kiddo': False, 'amp': False, 'done relax': False, 'ach': False, 'basebal game sunday lose saturday sunday realli sunnu': False, 'go gym today shoulder hurt get bang w hockey tournament last night need rest': False, 'karenbyrn watch churchonlin get chat work': False, 'girl wa next made eye contact right befor got move anoth seat': False, 'wa extrem earli today bet peopl miss bit': False, 'head pullmonst pack apart back tomorrow time wakeboard': False, 'chloe twitter bum everyon': False, 'lolyl still exam': False, 'badminton jan shim friend work time': False, 'must fight urg go botcon': False, 'wait friend ring go bed': False, 'maureen white tie affair last night woo woo like best night life talent nice lt lt lt': False, 'omg cant stop love adrian jajajajaja funni cant wait see next week': False, 'love xna offici tutori howev voic boringli slow guy ever video amp done drawn sprite': False, 'wow thunder grandpa use tell sound thunder wa god bowl': False, 'amylovesoliv  ...

# %%
featuresets = [(find_features(rev), category) for (rev, category) in documents]

# %% [markdown]
# ### Building and Traininng Naive Bayes Model
#
# In this step you will split your feature set into a training and a test set. Then you will create a Bayes classifier instance using `nltk.NaiveBayesClassifier.train` ([example](https://www.nltk.org/book/ch06.html)) to train with the training dataset.
#
# After training the model, call `classifier.show_most_informative_features()` to inspect the most important features. The output will look like:
#
# ```
# Most Informative Features
# 	    snow = True            False : True   =     34.3 : 1.0
# 	  easter = True            False : True   =     26.2 : 1.0
# 	 headach = True            False : True   =     20.9 : 1.0
# 	    argh = True            False : True   =     17.6 : 1.0
# 	unfortun = True            False : True   =     16.9 : 1.0
# 	    jona = True             True : False  =     16.2 : 1.0
# 	     ach = True            False : True   =     14.9 : 1.0
# 	     sad = True            False : True   =     13.0 : 1.0
# 	  parent = True            False : True   =     12.9 : 1.0
# 	  spring = True            False : True   =     12.7 : 1.0
# ```
#
# The [following video](https://www.youtube.com/watch?v=rISOsUaTrO4) will help you complete this step. The source code in this video can be found [here](https://pythonprogramming.net/naive-bayes-classifier-nltk-tutorial/).

# %% [markdown]
# [![Building and Training NB](nb-model-building.jpg)](https://www.youtube.com/watch?v=rISOsUaTrO4)

# %%
# your code here

# %%
len(featuresets)
# Out:
# 2000

# %%
# set that we'll train our classifier with
training_set = featuresets[:1900]

# set that we'll test against.
testing_set = featuresets[1900:]

# %%
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
classifier.show_most_informative_features(15)
# Out:
# Most Informative Features
#                      ugh = True              neg : pos    =      4.9 : 1.0
#                      sat = True              neg : pos    =      4.6 : 1.0
#                     bore = True              neg : pos    =      4.0 : 1.0
#                    dunno = True              neg : pos    =      3.0 : 1.0
#                goodnight = True              pos : neg    =      2.4 : 1.0
#                    stink = True              neg : pos    =      2.3 : 1.0
#                   shower = True              neg : pos    =      2.3 : 1.0
#                      bad = True              neg : pos    =      2.0 : 1.0
#                        b = True              neg : pos    =      2.0 : 1.0
#                     pack = True              pos : neg    =      1.8 : 1.0
#                      wow = True              neg : pos    =      1.8 : 1.0
#                    chang = True              pos : neg    =      1.8 : 1.0
#                   repair = True              pos : neg    =      1.8 : 1.0
#                   doctor = True              neg : pos    =      1.8 : 1.0
#                      buy = True              pos : neg    =      1.6 : 1.0

# %% [markdown]
# ### Testing Naive Bayes Model
#
# Now we'll test our classifier with the test dataset. This is done by calling `nltk.classify.accuracy(classifier, test)`.
#
# As mentioned in one of the tutorial videos, a Naive Bayes model is considered OK if your accuracy score is over 0.6. If your accuracy score is over 0.7, you've done a great job!

# %%
# your code here

# %%
print("Classifier accuracy percent:",(nltk.classify.accuracy(classifier, testing_set))*100)
# Out:
# Classifier accuracy percent: 59.0

# %% [markdown]
# ## Bonus Question 1: Improve Model Performance
#
# If you are still not exhausted so far and want to dig deeper, try to improve your classifier performance. There are many aspects you can dig into, for example:
#
# * Improve stemming and lemmatization. Inspect your bag of words and the most important features. Are there any words you should furuther remove from analysis? You can append these words to further remove to the stop words list.
#
# * Remember we only used the top 5,000 features to build model? Try using different numbers of top features. The bottom line is to use as few features as you can without compromising your model performance. The fewer features you select into your model, the faster your model is trained. Then you can use a larger sample size to improve your model accuracy score.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 2: Machine Learning Pipeline
#
# In a new Jupyter Notebook, combine all your codes into a function (or a class). Your new function will execute the complete machine learning pipeline job by receiving the dataset location and output the classifier. This will allow you to use your function to predict the sentiment of any tweet in real time.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 3: Apache Spark
#
# If you have completed the Apache Spark advanced topic lab, what you can do is to migrate your pipeline from local to a Databricks Notebook. Share your notebook with your instructor and classmates to show off your achievements!

# %%
# your code here
